# %%
import numpy as np
import pandas as pd

# %%
data_set=pd.read_csv("/home/ash/Downloads/git/DSBDA/StudentsPerformance.csv")

# %%
data_set.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          72             72            NaN
# 1               completed          69             90           88.0
# 2                    none          90             95           93.0
# 3                    none          47             57           44.0
# 4                    none          76             78           75.0

# %%
data_set.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  1
# dtype: int64

# %%
data_set.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  1
# dtype: int64

# %%
data_set.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000     999.000000
# mean     66.08900      69.169000      68.048048
# std      15.16308      14.600192      15.202102
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.500000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data_set.fillna({'writing score':data_set['writing score'].mean()},inplace=True)

# %%
data_set.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.048048
# std      15.16308      14.600192      15.194491
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data_set['gender']=data_set['gender'].astype('category')

# %%
data_set.dtypes
# Out:
# gender                         category
# race/ethnicity                   object
# parental level of education      object
# lunch                            object
# test preparation course          object
# math score                        int64
# reading score                     int64
# writing score                   float64
# dtype: object

# %%
df_enc=pd.get_dummies(data_set,columns=['lunch','test preparation course'])

# %%
df_enc.drop('test preparation course_none',axis=1)
# Out:
#      gender race/ethnicity parental level of education  math score  \
# 0    female        group B           bachelor's degree          72
# 1    female        group C                some college          69
# 2    female        group B             master's degree          90
# 3      male        group A          associate's degree          47
# 4      male        group C                some college          76
# ..      ...            ...                         ...         ...
# 995  female        group E             master's degree          88
# 996    male        group C                 high school          62
# 997  female        group C                 high school          59
# 998  female        group D                some college          68
# 999  female        group D                some college          77
#
#      reading score  writing score  lunch_free/reduced  lunch_standard  \
# 0               72      68.048048               False            True
# ...

# %%
df_enc.drop('lunch_standard',axis=1)
# Out:
#      gender race/ethnicity parental level of education  math score  \
# 0    female        group B           bachelor's degree          72
# 1    female        group C                some college          69
# 2    female        group B             master's degree          90
# 3      male        group A          associate's degree          47
# 4      male        group C                some college          76
# ..      ...            ...                         ...         ...
# 995  female        group E             master's degree          88
# 996    male        group C                 high school          62
# 997  female        group C                 high school          59
# 998  female        group D                some college          68
# 999  female        group D                some college          77
#
#      reading score  writing score  lunch_free/reduced  \
# 0               72      68.048048               False
# ...
